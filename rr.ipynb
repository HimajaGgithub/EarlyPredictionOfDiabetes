# %%
import cv2
import matplotlib.pyplot as plt
import json
import pprint
#loading image
img =  cv2.imread("D:\BNMIT\IBM\8377eac8-7567-4f4f-a1c7-92d5952e17e8.width-800.jpg") #loading image

#showing image using plt 
plt.imshow(img)

# %%
color_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow( color_img)

# %%
from deepface import DeepFace


#this analyses the given image and gives values
#when we use this for 1st time, it may give many errors and some google drive links to download some '.h5' and zip files, download and save them in the location where it shows that files are missing.
prediction = DeepFace.analyze(color_img)
# Out:
# Action: race: 100%|██████████| 4/4 [00:01<00:00,  2.98it/s]

# %%
print(prediction)
# Out:
# [{'emotion': {'angry': 0.0010955552170344163, 'disgust': 6.164609651877285e-13, 'fear': 2.828207390503934e-08, 'happy': 98.77918362617493, 'sad': 0.05742874927818775, 'surprise': 5.940146152738635e-07, 'neutral': 1.1622948572039604}, 'dominant_emotion': 'happy', 'region': {'x': 338, 'y': 60, 'w': 163, 'h': 163}, 'age': 34, 'gender': {'Woman': 0.0009951907486538403, 'Man': 99.99901056289673}, 'dominant_gender': 'Man', 'race': {'asian': 2.9713109750417743e-08, 'indian': 1.1741658756392326e-07, 'black': 100.0, 'white': 4.476185314434753e-14, 'middle eastern': 6.307395686553114e-16, 'latino hispanic': 3.6043477230629506e-09}, 'dominant_race': 'black'}]

# %%
kk=prediction[-1]['dominant_race']

# %%
print((kk))
# Out:
# black
